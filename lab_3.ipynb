# %%
import numpy as np
import pandas as pd
import re
import nltk
import nltk.data
from tqdm import tqdm
import pymorphy3

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Uvarov.MN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Все новости. Ниже разделю их на тренировочную и тестовую выборки
all_news = pd.DataFrame(pd.read_csv('result.csv'), columns=['title', 'text'])
print("Всего новостей ", len(all_news))

# news = pd.DataFrame(pd.read_csv('analisys_result.csv'), columns=['title', 'text'])
# print(news.iloc[[1]])
# print(news.iloc[1,1])
# Out:
# Всего новостей  1684

# %%
print(all_news.iloc[[943]])
# Out:
#                                                  title  \
# 943  Богатейший человек в мире Арно потерял за день...
#
#                                                   text
# 943  Состояние богатейшего человека в мире, владель...

# %%
# Тестоую выборку 50 новостей получаем рандомайзом. Дальше используем ее как основные новости
test = all_news.sample(n = 50, random_state=1)
print("Всего тестовой выборки " ,len(test))
# Out:
# Всего тестовой выборки  50

# %%
# Тренировочная быборка это все новости минус рандомно полученные тестовые новости 50 шт
news = pd.concat([all_news, test]).drop_duplicates(keep=False)
print("Всего чистых новостей, они же транировочные " ,len(news))
# Out:
# Всего чистых новостей, они же транировочные  1634

# %%
def text_to_sentences(text):
    # Функция делит текст на предложения, а предложения на слова.
    
    
    # Поделим текст на предложения при помощи NLTK.
    raw_sentences = nltk.sent_tokenize(str(text), language="russian")
    # Поделим предложения на слова при помощи регулярных выражений, заодно выкинем знаки препинания и цифры.
    sentences = []
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.append(re.findall('[a-zA-Zа-яА-яёЁ]+', raw_sentence.lower()))
    return sentences

# %%
# пример на одной новости
text_to_sentences(news['text'][1])
# Out:
# [['мая',
#   'церковь',
#   'чтит',
#   'память',
#   'преподобной',
#   'евфросинии',
#   'в',
#   'миру',
#   'евдокии',
#   'великой',
#   'княгини',
#   'московской'],
#  ['в',
#   'народе',
#   'день',
#   'носит',
#   'название',
#   'евдокии',
#   'свистуньи',
#   'считается',
#   'что',
#   'в',
#   'это',
#   'время',
#   'ветры',
#   'свистят'],
#  ['с', 'днем', 'связан', 'ряд', 'примет'],
#  ['какова', 'евдокия', 'таково', 'и', 'лето', 'говорили', 'крестьяне'],
#  ['народившаяся',
#   'в',
#   'дождливую',
#   'евдокию',
#   'луна',
#   'к',
#   'мокрому',
#   'лету',
#   'а',
#   'если',
#   'еще',
#   'дует',
#   'северный',
#   'ветер',
#   'к',
#   'лету',
#   'холодному'],
#  ['холодно',
#   'днем',
#   'летом',
#   'будет',
#   'частый',
#   'град',
#   'дождь',
#   'идет',
#   'лето',
#   'будет',
#   'мокрым'],
#  ['дятел', 'стучит', 'в', 'ясный', 'день', 'скоро', 'пойдет', 'ливень'],
#  ['свиньи', 'роют', 'грязь', 'носом', 'к', 'затяжному', 'дождю'],
#  ['ворон', 'каркает', 'над', 'крышей', 'ночью', 'будет', 'холодно']]

# %%
all_sentences = [text_to_sentences(str(x)) for x in news['text']]
print(all_sentences[:1])
# all_sentenc1es = sum([text_to_sentences(x) for x in news['text']])
# all_sentences = sum([text_to_sentences(x) for x in news['text'].astype('string')])
# Out:
# [[['хабаровчане', 'провели', 'праздничную', 'неделю', 'под', 'музыку', 'военных', 'оркестров', 'со', 'всей', 'россии'], ['за', 'дней', 'на', 'площадках', 'состоялось', 'выступлений', 'которые', 'объединили', 'более', 'музыкантов', 'сообщает', 'иа', 'хабаровский', 'край', 'сегодня'], ['более', 'тысяч', 'зрителей', 'по', 'другую', 'сторону', 'экрана', 'собрала', 'онлайн', 'трансляция', 'фестиваля'], ['марш', 'парад', 'концерты', 'дефиле', 'представления', 'посетили', 'около', 'тысяч', 'человек'], ['амурские', 'волны', 'из', 'года', 'в', 'год', 'поражают', 'размахом'], ['это', 'яркое', 'весеннее', 'шоу', 'заполняющее', 'площади', 'и', 'улицы', 'города', 'звуками', 'живой', 'музыки', 'и', 'шумом', 'бурных', 'оваций', 'чтобы', 'в', 'xi', 'раз', 'удивить', 'искушенного', 'зрителя', 'краевой', 'столицы', 'режиссёры', 'привлекли', 'к', 'участию', 'в', 'фестивале', 'талантливых', 'артистов', 'хабаровска'], ['коллаборации', 'знакомых', 'и', 'любимых', 'исполнителей', 'с', 'оркестровым', 'звучанием', 'вот', 'что', 'является', 'неотъемлемой', 'частью', 'и', 'изюминкой', 'фестиваля', 'создавать', 'события', 'такого', 'масштаба', 'невозможно', 'без', 'поддержки', 'и', 'надёжной', 'команды'], ['ооо', 'транснефть', 'дальний', 'восток', 'постоянные', 'партнёры', 'фестиваля', 'амурские', 'волны'], ['предприятие', 'активно', 'занимается', 'благотворительностью', 'и', 'поддержкой', 'социально', 'значимых', 'проектов', 'хабаровского', 'края', 'традиционными', 'участниками', 'фестиваля', 'стали', 'центральный', 'военный', 'оркестр', 'министерства', 'обороны', 'рф', 'москва', 'оркестр', 'суворовцев', 'московского', 'военно', 'музыкального', 'училища', 'им', 'генерал', 'лейтенанта', 'валерия', 'халилова', 'москва', 'военный', 'оркестр', 'войск', 'и', 'сил', 'на', 'северо', 'востоке', 'рф', 'петропавловск', 'камчатский', 'военный', 'оркестр', 'штаба', 'тоф', 'владивосток'], ['впервые', 'приехали', 'в', 'хабаровск', 'музыканты', 'го', 'военного', 'оркестра', 'объединенного', 'стратегического', 'командования', 'южного', 'военного', 'округа', 'из', 'города', 'ростов', 'на', 'дону'], ['дебютанты', 'xi', 'амурских', 'волн', 'и', 'однозначно', 'дали', 'старт', 'дружбе', 'между', 'городами'], ['мастерство', 'владения', 'хомусом', 'и', 'искусством', 'звукоимитации', 'продемонстрировали', 'гости', 'из', 'якутии', 'великолепные', 'энергичные', 'и', 'обаятельные', 'музыканты', 'из', 'тюмени', 'читы', 'улан', 'удэ', 'и', 'уссурийска', 'после', 'каждого', 'номера', 'срывали', 'бурные', 'аплодисменты', 'от', 'благодарной', 'аудитории'], ['поистине', 'завораживающим', 'зрелищем', 'неизменно', 'остаётся', 'выступление', 'сводного', 'хора', 'военно', 'музыкального', 'фестиваля'], ['это', 'подлинный', 'момент', 'единения', 'исполнителей', 'с', 'зрительным', 'залом', 'вдохновляющий', 'и', 'торжественный', 'каждый', 'участник', 'амурских', 'волн', 'обладает', 'особенной', 'харизмой', 'и', 'стилем', 'звучания'], ['настоящие', 'музыкальные', 'битвы', 'соревнования', 'жанров', 'песенных', 'аттракционов', 'происходили', 'на', 'глазах', 'тысяч', 'зрителей', 'которых', 'ежегодно', 'поражает', 'безграничная', 'фантазия', 'творческая', 'смелость', 'верность', 'и', 'любовь', 'музыкантов', 'к', 'оркестровому', 'искусству'], ['из', 'года', 'в', 'год', 'амурские', 'волны', 'бьют', 'рекорды', 'популярности'], ['фестиваль', 'собирает', 'участников', 'и', 'гостей', 'со', 'всей', 'страны', 'и', 'из', 'за', 'рубежа'], ['такое', 'признание', 'результат', 'труда', 'музыкантов', 'а', 'также', 'большая', 'работа', 'со', 'стороны', 'организаторов', 'министерства', 'обороны', 'рф', 'правительства', 'края', 'и', 'администрации', 'хабаровска'], ['добавлю', 'что', 'мы', 'уже', 'приступили', 'к', 'планированию', 'xii', 'фестиваля', 'отметил', 'министр', 'культуры', 'хабаровского', 'края', 'юрий', 'ермошкин']]]

# %%
all_sentences[0]
# Out:
# [['хабаровчане',
#   'провели',
#   'праздничную',
#   'неделю',
#   'под',
#   'музыку',
#   'военных',
#   'оркестров',
#   'со',
#   'всей',
#   'россии'],
#  ['за',
#   'дней',
#   'на',
#   'площадках',
#   'состоялось',
#   'выступлений',
#   'которые',
#   'объединили',
#   'более',
#   'музыкантов',
#   'сообщает',
#   'иа',
#   'хабаровский',
#   'край',
#   'сегодня'],
#  ['более',
#   'тысяч',
#   'зрителей',
#   'по',
#   'другую',
#   'сторону',
#   'экрана',
#   'собрала',
#   'онлайн',
#   'трансляция',
#   'фестиваля'],
#  ['марш',
#   'парад',
#   'концерты',
#   'дефиле',
#   'представления',
#   'посетили',
#   'около',
#   'тысяч',
#   'человек'],
#  ['амурские', 'волны', 'из', 'года', 'в', 'год', 'поражают', 'размахом'],
#  ['это',
#   'яркое',
#   'весеннее',
#   'шоу',
#   'заполняющее',
#   'площади',
#   'и',
#   'улицы',
#   'города',
#   'звуками',
#   'живой',
#   'музыки',
#   'и',
#   'шумом',
#   'бурных',
#   'оваций',
#   'чтобы',
#   'в',
#   'xi',
#   'раз',
#   'удивить',
#   'искушенного',
#   'зрителя',
#   'краевой',
#   'столицы',
#   'режиссёры',
#   'привлекли',
#   'к',
#   'участию',
#   'в',
#   'фестивале',
#   'талантливых',
#   'артистов',
#   'хабаровска'],
#  ['коллаборации',
#   'знакомых',
#   'и',
#   'любимых',
#   'исполнителей',
#   'с',
#   'оркестровым',
#   'звучанием',
#   'вот',
#   'что',
#   'является',
#   'неотъемлемой',
#   'частью',
#   'и',
#   'изюминкой',
#   'фестиваля',
#   'создавать',
#   'события',
#   'такого',
#   'масштаба',
#   'невозможно',
#   'без',
#   'поддержки',
#   'и',
#   'надёжной',
#   'команды'],
#  ['ооо',
#   'транснефть',
#   'дальний',
#   'восток',
#   'постоянные',
#   'партнёры',
#   'фестиваля',
#   'амурские',
#   'волны'],
#  ['предприятие',
#   'активно',
#   'занимается',
#   'благотворительностью',
#   'и',
#   'поддержкой',
#   'социально',
#   'значимых',
#   'проектов',
#   'хабаровского',
#   'края',
#   'традиционными',
#   'участниками',
#   'фестиваля',
#   'стали',
#   'центральный',
#   'военный',
#   'оркестр',
#   'министерства',
#   'обороны',
#   'рф',
#   'москва',
#   'оркестр',
#   'суворовцев',
#   'московского',
#   'военно',
#   'музыкального',
#   'училища',
#   'им',
#   'генерал',
#   'лейтенанта',
#   'валерия',
#   'халилова',
#   'москва',
#   'военный',
#   'оркестр',
#   'войск',
#   'и',
#   'сил',
#   'на',
#   'северо',
#   'востоке',
#   'рф',
#   'петропавловск',
#   'камчатский',
#   'военный',
#   'оркестр',
#   'штаба',
#   'тоф',
#   'владивосток'],
#  ['впервые',
#   'приехали',
#   'в',
#   'хабаровск',
#   'музыканты',
#   'го',
#   'военного',
#   'оркестра',
#   'объединенного',
#   'стратегического',
#   'командования',
#   'южного',
#   'военного',
#   'округа',
#   'из',
#   'города',
#   'ростов',
#   'на',
#   'дону'],
#  ['дебютанты',
#   'xi',
#   'амурских',
#   'волн',
#   'и',
#   'однозначно',
#   'дали',
#   'старт',
#   'дружбе',
#   'между',
#   'городами'],
#  ['мастерство',
#   'владения',
#   'хомусом',
#   'и',
#   'искусством',
#   'звукоимитации',
#   'продемонстрировали',
#   'гости',
#   'из',
#   'якутии',
#   'великолепные',
#   'энергичные',
#   'и',
#   'обаятельные',
#   'музыканты',
#   'из',
#   'тюмени',
#   'читы',
#   'улан',
#   'удэ',
#   'и',
#   'уссурийска',
#   'после',
#   'каждого',
#   'номера',
#   'срывали',
#   'бурные',
#   'аплодисменты',
#   'от',
#   'благодарной',
#   'аудитории'],
#  ['поистине',
#   'завораживающим',
#   'зрелищем',
#   'неизменно',
#   'остаётся',
#   'выступление',
#   'сводного',
#   'хора',
#   'военно',
#   'музыкального',
#   'фестиваля'],
#  ['это',
#   'подлинный',
#   'момент',
#   'единения',
#   'исполнителей',
#   'с',
#   'зрительным',
#   'залом',
#   'вдохновляющий',
#   'и',
#   'торжественный',
#   'каждый',
#   'участник',
#   'амурских',
#   'волн',
#   'обладает',
#   'особенной',
#   'харизмой',
#   'и',
#   'стилем',
#   'звучания'],
#  ['настоящие',
#   'музыкальные',
#   'битвы',
#   'соревнования',
#   'жанров',
#   'песенных',
#   'аттракционов',
#   'происходили',
#   'на',
#   'глазах',
#   'тысяч',
#   'зрителей',
#   'которых',
#   'ежегодно',
#   'поражает',
#   'безграничная',
#   'фантазия',
#   'творческая',
#   'смелость',
#   'верность',
#   'и',
#   'любовь',
#   'музыкантов',
#   'к',
#   'оркестровому',
#   'искусству'],
#  ['из',
#   'года',
#   'в',
#   'год',
#   'амурские',
#   'волны',
#   'бьют',
#   'рекорды',
#   'популярности'],
#  ['фестиваль',
#   'собирает',
#   'участников',
#   'и',
#   'гостей',
#   'со',
#   'всей',
#   'страны',
#   'и',
#   'из',
#   'за',
#   'рубежа'],
#  ['такое',
#   'признание',
#   'результат',
#   'труда',
#   'музыкантов',
#   'а',
#   'также',
#   'большая',
#   'работа',
#   'со',
#   'стороны',
#   'организаторов',
#   'министерства',
#   'обороны',
#   'рф',
#   'правительства',
#   'края',
#   'и',
#   'администрации',
#   'хабаровска'],
#  ['добавлю',
#   'что',
#   'мы',
#   'уже',
#   'приступили',
#   'к',
#   'планированию',
#   'xii',
#   'фестиваля',
#   'отметил',
#   'министр',
#   'культуры',
#   'хабаровского',
#   'края',
#   'юрий',
#   'ермошкин']]

# %%
from gensim.models.word2vec import Word2Vec # Собственно модель.
from gensim.models import KeyedVectors # Семантические вектора.

# %%
model_w2v = KeyedVectors.load_word2vec_format('araneum_upos_skipgram_300_2_2018.vec.gz')

# %%
model_w2v['огонь_NOUN']
# Out:
# array([-2.69010e-02,  1.08851e-01,  1.13100e-03, -2.76620e-02,
#        -2.50680e-02, -4.58600e-03, -1.26100e-03, -3.79600e-03,
#        -7.53080e-02, -2.39490e-02,  2.00400e-02,  6.10330e-02,
#         7.40810e-02,  9.56330e-02, -1.11446e-01,  4.60380e-02,
#        -2.24540e-02, -2.46080e-02, -8.82250e-02, -1.53180e-02,
#        -3.66000e-04, -9.46770e-02,  1.33686e-01,  5.88400e-03,
#        -5.05470e-02,  8.13820e-02, -2.88090e-02, -7.00070e-02,
#         8.74950e-02, -8.31860e-02, -2.48210e-02, -3.82660e-02,
#         6.13210e-02, -6.45530e-02,  2.66400e-03,  8.36140e-02,
#        -3.73850e-02,  3.63260e-02, -1.20000e-04, -6.90000e-02,
#         1.49810e-02,  3.03880e-02, -2.17280e-02,  2.79400e-02,
#        -5.22550e-02,  1.96660e-02,  1.52499e-01,  7.27100e-02,
#        -2.11140e-02,  5.69930e-02, -3.07870e-02,  4.09070e-02,
#         6.49290e-02,  1.91730e-02,  2.50080e-02, -2.94090e-02,
#         6.33780e-02,  1.09028e-01,  5.66630e-02, -3.62330e-02,
#         4.96900e-02, -7.09280e-02,  2.74420e-02, -1.98650e-02,
#        -4.51340e-02, -1.50980e-02, -3.99110e-02, -7.48090e-02,
#         2.94630e-02, -4.18650e-02,  9.38820e-02, -6.96000e-03,
#         4.16040e-02, -5.73700e-03,  3.39000e-02, -6.67390e-02,
#        -2.04790e-02, -4.25040e-02,  5.67500e-03, -2.83490e-02,
#        -2.34950e-02, -1.02213e-01,  4.98750e-02,  3.86900e-02,
#        -4.36590e-02,  1.31880e-02,  1.11148e-01, -9.44720e-02,
#        -5.93430e-02, -7.77140e-02,  3.85430e-02,  9.09070e-02,
#         5.09000e-04, -3.78620e-02,  8.04500e-03,  7.43830e-02,
#        -7.35100e-03,  1.70230e-02, -5.24390e-02,  7.93950e-02,
#        -1.05930e-02,  2.68270e-02, -2.39120e-02,  3.64000e-03,
#        -1.16770e-01, -4.78740e-02, -1.94120e-02, -2.09940e-02,
#        -4.56630e-02,  9.08380e-02,  1.80280e-02, -1.00870e-02,
#        -8.83500e-03, -7.56900e-02,  4.17490e-02,  4.27480e-02,
#         5.95060e-02, -5.91950e-02,  6.34880e-02,  6.82500e-03,
#         1.09871e-01, -2.10860e-02, -1.21474e-01, -6.05000e-03,
#         1.42470e-02, -3.60890e-02, -3.13030e-02,  4.21140e-02,
#         1.07471e-01,  2.07040e-02, -7.25410e-02, -1.93690e-01,
#         5.95580e-02, -3.45950e-02,  9.50300e-03,  2.53610e-02,
#        -2.54120e-02, -2.17180e-02, -2.21100e-02, -7.57500e-03,
#         3.60960e-02, -1.06891e-01,  4.65520e-02,  8.61400e-02,
#         1.70600e-02, -2.51140e-02,  2.39590e-02, -8.88980e-02,
#        -7.08180e-02,  4.93690e-02, -7.07880e-02,  7.44000e-04,
#         8.43790e-02,  3.18580e-02,  1.54160e-02,  3.75200e-03,
#         4.08160e-02, -1.07720e-02,  3.80000e-05, -2.36560e-02,
#         6.82770e-02, -5.49300e-03, -4.53580e-02, -3.88940e-02,
#        -4.54900e-02,  1.57553e-01, -5.80460e-02,  6.83370e-02,
#        -8.21530e-02,  6.11360e-02,  4.91810e-02,  5.84270e-02,
#        -7.00170e-02, -2.40380e-02, -2.87350e-02,  5.24180e-02,
#         1.14887e-01, -5.87410e-02, -4.20570e-02,  1.19858e-01,
#         2.60310e-02,  5.82470e-02,  3.14760e-02,  1.18300e-02,
#        -1.37664e-01, -2.10020e-02,  4.01790e-02,  5.56920e-02,
#         6.25000e-04,  1.60360e-02, -7.11240e-02, -1.13366e-01,
#        -7.36260e-02, -2.14090e-02,  5.83280e-02, -7.83660e-02,
#        -1.06356e-01,  2.92150e-02,  1.44810e-02,  1.23620e-02,
#         8.98920e-02, -6.26090e-02,  1.31730e-02,  6.17000e-03,
#        -4.62430e-02, -5.07060e-02, -1.61660e-02,  2.44100e-02,
#        -3.08970e-02,  1.58160e-02, -7.52400e-03, -1.04370e-02,
#        -1.40530e-02,  7.48180e-02,  1.10510e-02, -4.58580e-02,
#         9.35010e-02, -9.41710e-02,  4.14960e-02, -3.22700e-02,
#         4.61280e-02,  1.67610e-02, -5.80500e-03, -1.41060e-02,
#        -7.47100e-03, -8.74700e-03,  1.18096e-01,  3.00600e-03,
#        -2.59760e-02,  4.57440e-02, -2.63350e-02,  8.31200e-03,
#        -3.71280e-02,  1.34530e-02,  1.25900e-03,  2.10700e-02,
#         3.31090e-02, -9.70660e-02, -3.07540e-02,  7.46400e-03,
#         2.45250e-02, -5.24890e-02, -7.32100e-02, -2.20560e-02,
#        -8.45000e-04, -3.56770e-02, -2.88380e-02, -1.10739e-01,
#         5.24800e-02,  4.86410e-02, -4.13790e-02, -8.64090e-02,
#         1.14032e-01, -5.14860e-02, -4.17900e-02, -1.08950e-02,
#        -2.41470e-02,  8.05840e-02, -1.05780e-01, -1.00646e-01,
#         8.94340e-02,  1.58700e-02, -1.04970e-02, -7.05070e-02,
#         1.78710e-02, -1.24600e-02,  3.17500e-02, -2.81730e-02,
#         3.50200e-03, -3.23100e-03,  1.60475e-01,  3.33950e-02,
#        -2.26930e-02, -4.89170e-02,  7.14610e-02,  2.63810e-02,
#         8.20400e-03, -2.83280e-02, -2.98600e-03,  1.03827e-01,
#         1.20600e-03,  8.00400e-02,  2.86600e-03, -4.63270e-02,
#         1.06284e-01,  2.58980e-02, -1.51700e-03,  6.35640e-02,
#        -1.21680e-02, -1.10570e-01, -7.52900e-02,  3.05160e-02,
#        -4.66550e-02,  1.21010e-02, -1.18719e-01,  1.66450e-02,
#        -9.19320e-02, -4.12540e-02, -3.70690e-02, -3.44930e-02],
#       dtype=float32)

# %%
model_w2v.most_similar('огонь_NOUN')
# Out:
# [('пламень_NOUN', 0.678379476070404),
#  ('пылать_VERB', 0.5475441813468933),
#  ('потушить_VERB', 0.5439907312393188),
#  ('тушить_VERB', 0.5375474095344543),
#  ('зажигать_VERB', 0.5247330665588379),
#  ('костер_NOUN', 0.5232465863227844),
#  ('полыхать_VERB', 0.5192115306854248),
#  ('негасимый_ADJ', 0.5050449371337891),
#  ('шквальный_ADJ', 0.5008323788642883),
#  ('гореть_VERB', 0.49952054023742676)]

# %%
list(model_w2v.key_to_index.keys())[:10]
# Out:
# ['год_NOUN',
#  'мочь_VERB',
#  'человек_NOUN',
#  'время_NOUN',
#  'работа_NOUN',
#  'новый_ADJ',
#  'становиться_VERB',
#  'также_ADV',
#  'очень_ADV',
#  'день_NOUN']

# %%
lens = np.array([np.linalg.norm(model_w2v[word]) for word in model_w2v.key_to_index.keys()])
lens[lens > 1.01], lens[lens < 0.99], lens[0]
# Out:
# (array([], dtype=float32), array([], dtype=float32), 0.99999964)

# %%
model_w2v.most_similar(positive=[u'сербия_PROPN', u'москва_PROPN' ], negative=[u'белград_PROPN'])
# Out:
# [('россия::москва_PROPN', 0.7317757606506348),
#  ('россия_PROPN', 0.7260456681251526),
#  ('москва::москва_PROPN', 0.7081453204154968),
#  ('москва::россия_PROPN', 0.6551340818405151),
#  ('россия::санкт-петербург_PROPN', 0.6160128712654114),
#  ('рф::москва_PROPN', 0.6140520572662354),
#  ('рязань_PROPN', 0.6115249991416931),
#  ('россия::украина_PROPN', 0.6086370944976807),
#  ('белоруссия_PROPN', 0.6031983494758606),
#  ('москва::санкт-петербург_PROPN', 0.6031042337417603)]

# %%
# !pip install umap
# Out:
# Requirement already satisfied: umap in c:\users\uvarov.mn\anaconda3\lib\site-packages (0.1.1)

# %%
import umap
from copy import copy

# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (16, 12)

# %%
def get_most_frequent_words_from_model(model, texts, threshold=20):
    """ Функция выделяет слова, которые встречаются в текстах texts не реже, чем threshold раз,
        и при этом имеются в предобученной модели model. Также возвращает вектора этих слов.
    """
    vctr = CountVectorizer(lowercase=False)
    cntr = vctr.fit_transform(texts)
    
    res_words = []
    res_vects = []
    summed = cntr.sum(axis=0)
    klist = list(vctr.vocabulary_.keys())
    for i in range(summed.shape[1]):
        if summed[0, i] > threshold:
            try:
                res_vects.append(model[klist[i]])
                res_words.append(klist[i])
            except:
#                 print(klist[i])
                pass
    
    return res_words, res_vects

# %%
conv_pos = {'ADJF':'ADJ', 'ADJS':'ADJ', 'ADV':'ADV', 'NOUN':'NOUN', 
            'VERB':'VERB', 'PRTF':'ADJ', 'PRTS':'ADJ', 'GRND':'VERB'}

tmp_dict = {} # Кеш значимых слов.
nones = {} # Кеш незначимых слов.

morph = pymorphy3.MorphAnalyzer()

# Фильтруем по части речи и возвращаем только начальную форму.
def normalizePymorphy(text, need_pos=True):
    tokens = re.findall('[A-Za-zА-Яа-яЁё]+\-[A-Za-zА-Яа-яЁё]+|[A-Za-zА-Яа-яЁё]+', str(text))
    words = []
    for t in tokens:
        # Если токен уже был закеширован, быстро возьмем результат из него.
        if t in tmp_dict.keys():
            words.append(tmp_dict[t])
        # Аналогично, если он в кеше незначимых слов.
        elif t in nones.keys():
            pass
        # Слово еще не встретилось, будем проводить медленный морфологический анализ.
        else:
            pv = morph.parse(t)
            if pv[0].tag.POS != None:
                if pv[0].tag.POS in conv_pos.keys():
                    if need_pos:
                        word = pv[0].normal_form+"_"+conv_pos[pv[0].tag.POS]
                    else:
                        word = pv[0].normal_form
                    # Отправляем слово в результат, ...
                    words.append(word)
                    # ... и кешируем результат его разбора.
                    tmp_dict[t] = word
                else:
                    # Для незначимых слов можно даже ничего не хранить. Лишь бы потом не обращаться к морфологии.
                    nones[t] = ""
                    
    return words

# %%
sci_sentences = []
n_texts = []
for text in tqdm(news['text']):
    norm = normalizePymorphy(text)
    sci_sentences.append(norm)
    n_texts.append(' '.join(norm))
# Out:
# 100%|██████████| 1634/1634 [00:08<00:00, 189.25it/s]

# %%
news['text'] = n_texts
news['text']
# Out:
# 0       хабаровчанин_NOUN провести_VERB праздничный_AD...
# 1       май_NOUN церковь_NOUN чтить_VERB память_NOUN п...
# 2       путин_NOUN прокомментировать_VERB атака_NOUN б...
# 3       школьник_NOUN сдавать_VERB егэ_NOUN остальной_...
# 4       образ_NOUN архангел_NOUN михаил_NOUN святой_AD...
#                               ...
# 1679    слово_NOUN посол_NOUN подрывать_VERB дух_NOUN ...
# 1680    лидер_NOUN турецкий_ADJ оппозиция_NOUN глава_N...
# 1681    касаться_VERB крупный_ADJ поставка_NOUN танк_N...
# 1682    свириденко_NOUN пояснить_VERB инициатива_NOUN ...
# 1683    вершинин_NOUN указать_VERB быть_VERB гарантия_...
# Name: text, Length: 1634, dtype: object

# %%
# !pip install umap
# Out:
# Requirement already satisfied: umap in c:\users\uvarov.mn\anaconda3\lib\site-packages (0.1.1)

# %%
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
import seaborn as sns
from matplotlib.colors import ListedColormap
from numpy.random import choice

# %%
def cluster_texts_and_draw(vectors, umaped_vct, eps):
    """ Функция кластеризует вектора vectors при помощи DBSCAN, используя eps в качестве параметра,
        и отображает их на плоскость, используя umaped_vct.
    """
    # Кластеризуем данные при помощи DBSCAN. 
    # Это не значит, что он лучше k-Means, он просто здесь быстрее.
    db = DBSCAN(eps=eps, min_samples=3)
    db_clusters = db.fit_predict(vectors)
     # Генерируем контрастную карту цветов.
    myclr = ListedColormap(choice(list(sns.xkcd_rgb.values()), max(db_clusters)+1))
    print(max(db_clusters))
    fig, ax = plt.subplots()
    ax.scatter(umaped_vct[:, 0], umaped_vct[:, 1], s=3, c=db_clusters, cmap=myclr)
    plt.show()
    return db_clusters

def show_texts_in_clusters(texts, target, clust_no, text_no):
    """ Функция отображает группировку текстов texts по кластсерам target.
        Выводит не более text_no текстов из первых clust_no кластеров.
    """

    clusters = list(set(target))

    for c in clusters[:clust_no]:
        print('          __ ', c, ' __')
        cntr = 0
        for i, a in enumerate(texts):
            if target[i] == c:
                print(a[:200])
                cntr += 1
                if cntr == text_no:
                    break
        print()

# %%
news_words, news_vects = get_most_frequent_words_from_model(model_w2v, news['text'], 10)
len(news_words)
# Out:
# 2462

# %%
len(news_vects)
# Out:
# 2462

# %%
# Кластеризуем, в среднем по два слова на кластер.

# news_clust_no = int(len(news_vects)/2)
sci_clust_no = int(len(news_vects)/2)
km_clustering = KMeans(n_clusters=sci_clust_no)
news_clusters = km_clustering.fit_predict(news_vects)

# %%
coi = 1
[word for word, clust in zip(news_words, news_clusters) if clust == coi]
# Out:
# ['храбрый_ADJ', 'благоразумный_ADJ']

# %%
news_words_sorted = sorted(zip(news_clusters, news_words), key= lambda x:x[0])
# sci_set = set(sci_words)
news_words_d = {w[1]:w[0] for w in news_words_sorted}

# %%
clust_no = 22
print([word[1] for word in news_words_sorted if word[0]==clust_no])
# Out:
# ['волатильность_NOUN', 'просадка_NOUN', 'котировка_NOUN', 'федрезерв_NOUN', 'спред_NOUN']

# %%
# Посчитаем координаты центроидов.
cur_clust = news_words_sorted[0][0]
cur_coord = np.array(model_w2v[news_words_sorted[0][1]])
cur_count = 1
clust_coord = []

for i, word in enumerate(news_words_sorted[1:]):
    if cur_clust == news_words_sorted[i+1][0]:
        cur_coord += model_w2v[news_words_sorted[i+1][1]]
        cur_count += 1
    else:
        clust_coord.append(cur_coord/cur_count)
        cur_clust = news_words_sorted[i+1][0]
        cur_coord = np.array(model_w2v[news_words_sorted[i+1][1]])
        cur_count = 1
        
clust_coord.append(cur_coord/cur_count)

# %%
def text_to_vec_centr(text, model_w2v, clust_coord, news_words_d):
    text_vec = np.zeros((model_w2v.vector_size,), dtype="float32")
    n_words = 0

    for word in normalizePymorphy(text):
        if word in news_words_d.keys():
            n_words = n_words + 1
            text_vec = np.add(text_vec, clust_coord[news_words_d[word]]) 
        else:
            try:
                text_vec = np.add(text_vec, model_w2v[word]) 
                n_words = n_words + 1
            except Exception:
                pass
    
    if n_words != 0:
        text_vec /= n_words
    return text_vec

# %%
# Строим вектора для слов.
news_vect2 = []
for text in tqdm(news.text):
    news_vect2.append(text_to_vec_centr(text, model_w2v, clust_coord, news_words_d))
# Out:
# 100%|██████████| 1634/1634 [00:08<00:00, 196.62it/s]

# %%
from umap.umap_ import UMAP

# %%
umaped_vct2 = UMAP().fit_transform(news_vect2)
clusters = cluster_texts_and_draw(news_vect2, umaped_vct2, 0.09)
# Out:
# 6

# %%
show_texts_in_clusters(news.text, clusters, 10, 3)
# Out:
#           __  0  __
# интересный_ADJ познавательный_ADJ тест_NOUN мочь_VERB
# интересный_ADJ познавательный_ADJ тест_NOUN мочь_VERB
# интересный_ADJ познавательный_ADJ тест_NOUN мочь_VERB
#
#           __  1  __
# олеся_NOUN маевский_NOUN интересный_ADJ познавательный_ADJ тест_NOUN мочь_VERB
# олеся_NOUN маевский_NOUN интересный_ADJ познавательный_ADJ тест_NOUN мочь_VERB
# олеся_NOUN маевский_NOUN интересный_ADJ познавательный_ADJ тест_NOUN мочь_VERB
#
#           __  2  __
# день_NOUN страна_NOUN зарегистрировать_VERB случай_NOUN заражение_NOUN смерть_NOUN весь_ADJ начало_NOUN пандемия_NOUN число_NOUN случай_NOUN выздоровление_NOUN коронавирус_NOUN увеличиться_VERB сутки_
# день_NOUN страна_NOUN зарегистрировать_VERB случай_NOUN заражение_NOUN весь_ADJ начало_NOUN пандемия_NOUN смертность_NOUN ковид_NOUN россия_NOUN опуститься_VERB минимум_NOUN весна_NOUN год_NOUN сутки_
# день_NOUN страна_NOUN зарегистрировать_VERB случай_NOUN заражение_NOUN смерть_NOUN весь_ADJ начало_NOUN пандемия_NOUN число_NOUN случай_NOUN выздоровление_NOUN коронавирус_NOUN увеличиться_VERB сутки_
#
#           __  3  __
# вооружённый_ADJ сила_NOUN российский_ADJ федерация_NOUN нанести_ADJ групповой_ADJ удар_NOUN применение_NOUN высокоточный_ADJ оружие_NOUN большой_ADJ дальность_NOUN воздушный_ADJ базирование_NOUN центр
# вооружённый_ADJ сила_NOUN российский_ADJ федерация_NOUN нанести_VERB удар_NOUN высокоточный_ADJ оружие_NOUN большой_ADJ дальность_NOUN морской_ADJ базирование_NOUN пункт_NOUN дислокация_NOUN центр_NOU
# вооружённый_ADJ сила_NOUN российский_ADJ федерация_NOUN нанести_ADJ групповой_ADJ удар_NOUN высокоточный_ADJ оружие_NOUN большой_ADJ дальность_NOUN морской_ADJ базирование_NOUN крупный_ADJ склад_NOUN
#
#           __  4  __
# отмечаться_VERB черниговский_ADJ область_NOUN тревога_NOUN прозвучать_VERB киевский_ADJ местный_ADJ время_NOUN совпадать_VERB киев_NOUN тревога_NOUN начаться_VERB удар_NOUN украинский_ADJ инфраструкту
# среда_NOUN сигнал_NOUN тревога_NOUN прозвучать_VERB полтавский_ADJ днепропетровский_ADJ кировоградский_ADJ днепропетровский_ADJ область_NOUN поздний_ADJ отменить_VERB тревога_NOUN одесский_ADJ николае
# сигнал_NOUN тревога_NOUN днепропетровский_ADJ область_NOUN подконтрольный_ADJ киев_NOUN часть_NOUN запорожский_ADJ прозвучать_VERB совпадать_VERB некоторый_ADJ время_NOUN тревога_NOUN объявить_VERB су
#
#           __  5  __
# вырасти_VERB курс_NOUN доллар_NOUN курс_NOUN доллар_NOUN опускаться_VERB рубль_NOUN вырасти_VERB второй_ADJ декада_NOUN май_NOUN год_NOUN рубль_NOUN оказаться_VERB сложный_ADJ выплата_NOUN дивиденд_NO
# доллар_NOUN евро_NOUN начать_VERB этот_ADJ неделя_NOUN майский_ADJ праздник_NOUN доллар_NOUN евро_NOUN начать_VERB рубль_NOUN публикация_NOUN инфляционный_ADJ данные_NOUN сша_NOUN оказаться_VERB ожида
# идти_VERB наш_ADJ план_NOUN оперативный_ADJ восстановление_NOUN рубль_NOUN суть_NOUN нерыночный_ADJ апрельский_ADJ ослабление_NOUN нацвалюта_NOUN фон_NOUN выход_NOUN нерезидент_NOUN актив_NOUN валюта_
#
#           __  6  __
# быть_VERB мониторить_VERB этот_ADJ ситуация_NOUN необходимость_NOUN выйти_VERB предложение_NOUN который_ADJ фас_NOUN смотреть_VERB поддерживать_VERB который_ADJ направить_ADJ ограничение_NOUN экспорт_
# биржевой_ADJ цена_NOUN бензин_NOUN марка_NOUN аи_NOUN обновить_VERB исторический_ADJ подняться_VERB тыс_NOUN рубль_NOUN тонна_NOUN европейский_ADJ часть_NOUN россия_NOUN котировка_NOUN марка_NOUN аи_N
# обновить_ADJ стоимость_NOUN топливо_NOUN аи_NOUN аи_NOUN биржа_NOUN продолжать_VERB момент_NOUN выход_NOUN материал_NOUN цена_NOUN аи_NOUN находиться_VERB район_NOUN тысяча_NOUN рубль_NOUN тонна_NOUN
#
#           __  -1  __
# хабаровчанин_NOUN провести_VERB праздничный_ADJ неделя_NOUN музыка_NOUN военный_ADJ оркестр_NOUN весь_ADJ россия_NOUN день_NOUN площадка_NOUN состояться_VERB выступление_NOUN который_ADJ объединить_VE
# май_NOUN церковь_NOUN чтить_VERB память_NOUN преподобный_ADJ евфросиния_NOUN мир_NOUN евдокия_NOUN великий_ADJ княгиня_NOUN московский_ADJ народ_NOUN день_NOUN носить_VERB название_NOUN евдокия_NOUN с
# путин_NOUN прокомментировать_VERB атака_NOUN беспилотник_NOUN слово_NOUN подобный_ADJ атака_NOUN киев_NOUN провоцировать_VERB москва_NOUN зеркальный_ADJ действие_NOUN мид_NOUN заявить_VERB право_NOUN

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

from sklearn.ensemble import RandomForestClassifier

# %%
def classify_texts(data, target):
    # Делим данные на обучающую и проверочную выборки.
    X_train, X_test, y_train, y_test = train_test_split(str(data), str(target), test_size=0.2, random_state=333)
    #Обучаем классификатор и оцениваем точность результатов.
    tree = RandomForestClassifier(criterion='entropy', random_state=333)
    tree.fit(X_train, y_train)
    y_hat = tree.predict(X_test)
    print(f"accuracy = {accuracy_score(y_hat, y_test)}")
    print(confusion_matrix(y_test, y_hat))

# %%
# Помещаем тестовую выборку в массив
targets = np.array(news)
len(targets)
# Out:
# 1634

# %%
len(news_vect2)
# Out:
# 1634

# %%
classify_texts(news_vect2, targets)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3108\2444783362.py in <module>
# ----> 1 classify_texts(news_vect2, targets)
#
# ~\AppData\Local\Temp\ipykernel_3108\3342914512.py in classify_texts(data, target)
#       1 def classify_texts(data, target):
#       2     # Делим данные на обучающую и проверочную выборки.
# ----> 3     X_train, X_test, y_train, y_test = train_test_split(str(data), str(target), test_size=0.2, random_state=333)
#       4     #Обучаем классификатор и оцениваем точность результатов.
#       5     tree = RandomForestClassifier(criterion='entropy', random_state=333)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2415         raise ValueError("At least one array required as input")
#    2416
# -> 2417     arrays = indexable(*arrays)
#    2418
#    2419     n_samples = _num_samples(arrays[0])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     376
#     377     result = [_make_indexable(X) for X in iterables]
# --> 378     check_consistent_length(*result)
#     379     return result
#     380
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [8421112, 14921]
